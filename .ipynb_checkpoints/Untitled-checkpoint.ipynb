# %%
import os
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option('display.max_colwidth', None)

# Funzione per leggere tutti i file Excel nella cartella "moduli_iscrizione" e unirli in un unico DataFrame
def unisci_excel_da_cartella(cartella):
    dfs = []  # Lista per contenere i DataFrame
    for filename in os.listdir(cartella):
        if filename.endswith('.xlsx'):
            filepath = os.path.join(cartella, filename)
            df = pd.read_excel(filepath)
            dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# Utilizzo della funzione
cartella = "moduli_iscrizione"
df = unisci_excel_da_cartella(cartella)
# Out:
# C:\Users\932197\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\932197\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\932197\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\932197\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
df = df.applymap(str.upper)
df
# Out:
#                                     Società             Cognome  \
# 0    KARATE SHOTOKAN BADOERE MORGANO A.S.D.        LEMKHANTERE
# 1    KARATE SHOTOKAN BADOERE MORGANO A.S.D.              BASSO
# 2    KARATE SHOTOKAN BADOERE MORGANO A.S.D.             SOLDA’
# 3    KARATE SHOTOKAN BADOERE MORGANO A.S.D.          CALLEGARO
# 4    KARATE SHOTOKAN BADOERE MORGANO A.S.D.            PEZZATO
# 5    KARATE SHOTOKAN BADOERE MORGANO A.S.D.              LANDO
# 6    KARATE SHOTOKAN BADOERE MORGANO A.S.D.             CASALI
# 7    KARATE SHOTOKAN BADOERE MORGANO A.S.D.             RENOSTO
# 8    KARATE SHOTOKAN BADOERE MORGANO A.S.D.              FANTON
# 9    KARATE SHOTOKAN BADOERE MORGANO A.S.D.          BARGELLESI
# 10   KARATE SHOTOKAN BADOERE MORGANO A.S.D.            BASEGGIO
# 11   KARATE SHOTOKAN BADOERE MORGANO A.S.D.                CEKU
# 12   KARATE SHOTOKAN BADOERE MORGANO A.S.D.            CAZZOLA
# 13   KARATE SHOTOKAN BADOERE MORGANO A.S.D.          CERCARIOLO
# 14   KARATE SHOTOKAN BADOERE MORGANO A.S.D.              ZATTA
# 15   KARATE SHOTOKAN BADOERE MORGANO A.S.D.            VEDOVATO
# 16   KARATE SHOTOKAN BADOERE MORGANO A.S.D.             PETENA’
# 17   KARATE SHOTOKAN BADOERE MORGANO A.S.D.             TESSARO
# 18   KARATE SHOTOKAN BADOERE MORGANO A.S.D.             RENOSTO
# 19   KARATE SHOTOKAN BADOERE MORGANO A.S.D.            BASEGGIO
# 20   KARATE SHOTOKAN BADOERE MORGANO A.S.D.        SARRI ASHLEY
# 21   KARATE SHOTOKAN BADOERE MORGANO A.S.D.           VEDELAGO
# 22   KARATE SHOTOKAN BADOERE MORGANO A.S.D.              FANTON
# 23   KARATE SHOTOKAN BADOERE MORGANO A.S.D.             CARRARO
# 24                ASD KI KAI DOJO CARBONERA           ZARATTINI
# 25                ASD KI KAI DOJO CARBONERA                NAQO
# 26                ASD KI KAI DOJO CARBONERA             CISLARI
# 27                ASD KI KAI DOJO CARBONERA            GRANELLO
# 28                ASD KI KAI DOJO CARBONERA             MASELLI
# 29                ASD KI KAI DOJO CARBONERA            CADAMURO
# 30                ASD KI KAI DOJO CARBONERA  TEMPESTA DE SANTIS
# 31                ASD KI KAI DOJO CARBONERA         SCALDAFERRI
# 32                ASD KI KAI DOJO CARBONERA            DI CAPUA
# 33                ASD KI KAI DOJO CARBONERA              AGRIMI
# 34                ASD KI KAI DOJO CARBONERA             TURCHET
# 35                ASD KI KAI DOJO CARBONERA                ALBU
# 36           SCUOLA KARATE GALLIERA/ROSSANO             SIMEONI
# 37           SCUOLA KARATE GALLIERA/ROSSANO               SANTI
# 38           SCUOLA KARATE GALLIERA/ROSSANO             TONIOLO
# 39           SCUOLA KARATE GALLIERA/ROSSANO              PIOTTO
# 40           SCUOLA KARATE GALLIERA/ROSSANO            CUSINATO
# 41           SCUOLA KARATE GALLIERA/ROSSANO             GRIGOLO
# 42           SCUOLA KARATE GALLIERA/ROSSANO              BAGGIO
# 43           SCUOLA KARATE GALLIERA/ROSSANO                POPA
# 44           SCUOLA KARATE GALLIERA/ROSSANO              SCONZA
# 45           SCUOLA KARATE GALLIERA/ROSSANO                LAGO
# 46           SCUOLA KARATE GALLIERA/ROSSANO            GIANNINO
# 47           SCUOLA KARATE GALLIERA/ROSSANO           TAULLARAJ
# 48           SCUOLA KARATE GALLIERA/ROSSANO         DI BATTISTA
# 49           SCUOLA KARATE GALLIERA/ROSSANO              SARTOR
# 50           SCUOLA KARATE GALLIERA/ROSSANO               HUZUM
# 51           SCUOLA KARATE GALLIERA/ROSSANO         BEN OUNAISA
# 52           SCUOLA KARATE GALLIERA/ROSSANO               GOBBI
# 53                 SCUOLA KARATE RESANA ASD           BALDASSA
# 54                 SCUOLA KARATE RESANA ASD              FABRIS
# 55                 SCUOLA KARATE RESANA ASD            POZZOBON
# 56                 SCUOLA KARATE RESANA ASD              TANASE
# 57                 SCUOLA KARATE RESANA ASD         PASQUALETTO
# 58                 SCUOLA KARATE RESANA ASD             TRENTIN
# 59                 SCUOLA KARATE RESANA ASD                 BA
# 60                 SCUOLA KARATE RESANA ASD           MUNARETTO
# 61                 SCUOLA KARATE RESANA ASD            TREVISAN
# 62                 SCUOLA KARATE RESANA ASD              STOCCO
# 63                 SCUOLA KARATE RESANA ASD            ZAMPIERI
# 64                 SCUOLA KARATE RESANA ASD              SPANIO
# 65                 SCUOLA KARATE RESANA ASD              MARCON
# 66                 SCUOLA KARATE RESANA ASD                 LIN
# 67                 SCUOLA KARATE RESANA ASD                 LIN
# 68                 SCUOLA KARATE RESANA ASD                  BA
# 69                 SCUOLA KARATE RESANA ASD           ALIHODZIC
# 70                 SCUOLA KARATE RESANA ASD           SIGNORILE
# 71                 SCUOLA KARATE RESANA ASD          CRIVELLARO
# 72                 SCUOLA KARATE RESANA ASD          CASAGRANDE
# 73                 SCUOLA KARATE RESANA ASD             ONNETTI
# 74                 SCUOLA KARATE RESANA ASD             FASSINA
# 75                 SCUOLA KARATE RESANA ASD                CAMI
# 76                 SCUOLA KARATE RESANA ASD             DAMETTO
# 77     ASD KARATE TREVIGNANO & MONTEBELLUNA           CAVALLIN
# 78     ASD KARATE TREVIGNANO & MONTEBELLUNA           SEMENZATO
# 79     ASD KARATE TREVIGNANO & MONTEBELLUNA             DURANTE
# 80     ASD KARATE TREVIGNANO & MONTEBELLUNA             BINOTTO
# 81     ASD KARATE TREVIGNANO & MONTEBELLUNA                TANG
# 82     ASD KARATE TREVIGNANO & MONTEBELLUNA            MUTELICA
# 83     ASD KARATE TREVIGNANO & MONTEBELLUNA       JEMENEZ TONON
# 84     ASD KARATE TREVIGNANO & MONTEBELLUNA          GASPARETTO
# 85     ASD KARATE TREVIGNANO & MONTEBELLUNA             MARCON
# 86     ASD KARATE TREVIGNANO & MONTEBELLUNA          MARTIGNAGO
# 87     ASD KARATE TREVIGNANO & MONTEBELLUNA               MERLO
# 88     ASD KARATE TREVIGNANO & MONTEBELLUNA           ZAMPROGNO
# 89     ASD KARATE TREVIGNANO & MONTEBELLUNA            SCHIAVON
# 90     ASD KARATE TREVIGNANO & MONTEBELLUNA               BERRA
# 91     ASD KARATE TREVIGNANO & MONTEBELLUNA           SERNAGLIA
# 92     ASD KARATE TREVIGNANO & MONTEBELLUNA                TANG
# 93     ASD KARATE TREVIGNANO & MONTEBELLUNA            MIHALYI
# 94     ASD KARATE TREVIGNANO & MONTEBELLUNA            MIHALYI
# 95     ASD KARATE TREVIGNANO & MONTEBELLUNA            SEMENZIN
# 96     ASD KARATE TREVIGNANO & MONTEBELLUNA             MARTINI
# 97     ASD KARATE TREVIGNANO & MONTEBELLUNA             OUALMAM
# 98     ASD KARATE TREVIGNANO & MONTEBELLUNA             OUALMAM
# 99              ASD SCUOLA KARATE MIGNAGOLA          PIERAGNOLO
# 100             ASD SCUOLA KARATE MIGNAGOLA             STEINER
# 101             ASD SCUOLA KARATE MIGNAGOLA             RONCATO
# 102             ASD SCUOLA KARATE MIGNAGOLA             TOTTOLO
# 103             ASD SCUOLA KARATE MIGNAGOLA           MARCHETTO
# 104             ASD SCUOLA KARATE MIGNAGOLA             BERALDO
# 105             ASD SCUOLA KARATE MIGNAGOLA           TESCHIONI
# 106             ASD SCUOLA KARATE MIGNAGOLA            COLLADON
# 107             ASD SCUOLA KARATE MIGNAGOLA            COLLADON
# 108             ASD SCUOLA KARATE MIGNAGOLA           CASTELLER
# 109             ASD SCUOLA KARATE MIGNAGOLA             GIANESE
# 110             ASD SCUOLA KARATE MIGNAGOLA             GIANESE
# 111             ASD SCUOLA KARATE MIGNAGOLA               BLEVE
# 112             ASD SCUOLA KARATE MIGNAGOLA                COGO
# 113             ASD SCUOLA KARATE MIGNAGOLA             POPESCU
# 114             ASD SCUOLA KARATE MIGNAGOLA              SARACI
# 115             ASD SCUOLA KARATE MIGNAGOLA             MANENTE
# 116             ASD SCUOLA KARATE MIGNAGOLA              PJETRI
#
#                   Nome                    Anno_Nascita  \
# 0                  DUA  FASCIA A: NATI DAL 2015 IN POI
# 1             LEONARDO    FASCIA B: NATI NEL 2014-2013
# 2               ETTORE  FASCIA A: NATI DAL 2015 IN POI
# 3            FRANCESCO    FASCIA B: NATI NEL 2014-2013
# 4                 DEVA    FASCIA B: NATI NEL 2014-2013
# 5               NICOLA    FASCIA C: NATI NEL 2012-2011
# 6               DANIEL  FASCIA A: NATI DAL 2015 IN POI
# 7                NOEMI    FASCIA B: NATI NEL 2014-2013
# 8               MATTEO    FASCIA C: NATI NEL 2012-2011
# 9              FABIOLA    FASCIA B: NATI NEL 2014-2013
# 10             GIACOMO  FASCIA A: NATI DAL 2015 IN POI
# 11              LEDION    FASCIA C: NATI NEL 2012-2011
# 12          SEBASTIANO    FASCIA C: NATI NEL 2012-2011
# 13              SAMUEL    FASCIA C: NATI NEL 2012-2011
# 14              GIULIO    FASCIA D: NATI NEL 2010-2009
# 15              CESARE    FASCIA D: NATI NEL 2010-2009
# 16               LINDA    FASCIA C: NATI NEL 2012-2011
# 17            VITTORIO    FASCIA B: NATI NEL 2014-2013
# 18             LORENZO    FASCIA C: NATI NEL 2012-2011
# 19             EDOARDO    FASCIA C: NATI NEL 2012-2011
# 20              MIRYAM    FASCIA D: NATI NEL 2010-2009
# 21                 EVA    FASCIA D: NATI NEL 2010-2009
# 22                EMMA    FASCIA D: NATI NEL 2010-2009
# 23             GIORGIA    FASCIA D: NATI NEL 2010-2009
# 24            LEONARDO  FASCIA A: NATI DAL 2015 IN POI
# 25                ALEX  FASCIA A: NATI DAL 2015 IN POI
# 26               MAXIM  FASCIA A: NATI DAL 2015 IN POI
# 27              MATTEO    FASCIA C: NATI NEL 2012-2011
# 28              SERENA  FASCIA A: NATI DAL 2015 IN POI
# 29             TOMMASO  FASCIA A: NATI DAL 2015 IN POI
# 30            ESTRELLA    FASCIA B: NATI NEL 2014-2013
# 31              JACOPO    FASCIA B: NATI NEL 2014-2013
# 32              ANDREA    FASCIA D: NATI NEL 2010-2009
# 33             GIACOMO    FASCIA D: NATI NEL 2010-2009
# 34              DAVIDE    FASCIA C: NATI NEL 2012-2011
# 35            GABRIELE    FASCIA D: NATI NEL 2010-2009
# 36                ASIA    FASCIA D: NATI NEL 2010-2009
# 37         CHRISTOPHER    FASCIA B: NATI NEL 2014-2013
# 38              PIETRO    FASCIA C: NATI NEL 2012-2011
# 39                EROS    FASCIA B: NATI NEL 2014-2013
# 40              NICOLÒ  FASCIA A: NATI DAL 2015 IN POI
# 41              ENRICO    FASCIA C: NATI NEL 2012-2011
# 42             EDOARDO  FASCIA A: NATI DAL 2015 IN POI
# 43         MARIA LUANA    FASCIA C: NATI NEL 2012-2011
# 44             TOMMASO    FASCIA C: NATI NEL 2012-2011
# 45        MICHELANGELO    FASCIA C: NATI NEL 2012-2011
# 46   GIOVANNI BATTISTA    FASCIA C: NATI NEL 2012-2011
# 47                IGLI    FASCIA B: NATI NEL 2014-2013
# 48            RAFFAELE    FASCIA B: NATI NEL 2014-2013
# 49            GIOVANNI  FASCIA A: NATI DAL 2015 IN POI
# 50                ALEX    FASCIA C: NATI NEL 2012-2011
# 51             MOHAMED    FASCIA D: NATI NEL 2010-2009
# 52              ANDREA    FASCIA D: NATI NEL 2010-2009
# 53              SAMUEL  FASCIA A: NATI DAL 2015 IN POI
# 54              MATTIA  FASCIA A: NATI DAL 2015 IN POI
# 55            GABRIELE    FASCIA B: NATI NEL 2014-2013
# 56                VLAD  FASCIA A: NATI DAL 2015 IN POI
# 57             NICOLAS  FASCIA A: NATI DAL 2015 IN POI
# 58             LORENZO  FASCIA A: NATI DAL 2015 IN POI
# 59               ABDUL    FASCIA C: NATI NEL 2012-2011
# 60              MATTEO    FASCIA B: NATI NEL 2014-2013
# 61               DIEGO    FASCIA B: NATI NEL 2014-2013
# 62       PIERFRANCESCO    FASCIA C: NATI NEL 2012-2011
# 63           FRANCESCO    FASCIA B: NATI NEL 2014-2013
# 64              NICOLE    FASCIA B: NATI NEL 2014-2013
# 65            NICHOLAS    FASCIA C: NATI NEL 2012-2011
# 66               JIONG    FASCIA D: NATI NEL 2010-2009
# 67               XIANG    FASCIA B: NATI NEL 2014-2013
# 68           SALIMATOU    FASCIA D: NATI NEL 2010-2009
# 69               DEMIR    FASCIA D: NATI NEL 2010-2009
# 70                ELIA    FASCIA C: NATI NEL 2012-2011
# 71                EVAN    FASCIA D: NATI NEL 2010-2009
# 72                EDEN    FASCIA D: NATI NEL 2010-2009
# 73               GIADA    FASCIA D: NATI NEL 2010-2009
# 74           FRANCESCO    FASCIA D: NATI NEL 2010-2009
# 75            BEATRICE    FASCIA D: NATI NEL 2010-2009
# 76              PIETRO    FASCIA D: NATI NEL 2010-2009
# 77               ANITA    FASCIA D: NATI NEL 2010-2009
# 78               KIARA    FASCIA C: NATI NEL 2012-2011
# 79              MATTEO    FASCIA D: NATI NEL 2010-2009
# 80              GIOELE    FASCIA C: NATI NEL 2012-2011
# 81                YIZI    FASCIA D: NATI NEL 2010-2009
# 82               SASHA    FASCIA D: NATI NEL 2010-2009
# 83             LORENZO    FASCIA C: NATI NEL 2012-2011
# 84             REBECCA    FASCIA B: NATI NEL 2014-2013
# 85               SOFIA  FASCIA A: NATI DAL 2015 IN POI
# 86            ISABELLA    FASCIA D: NATI NEL 2010-2009
# 87             LORENZO    FASCIA C: NATI NEL 2012-2011
# 88               LAURA    FASCIA D: NATI NEL 2010-2009
# 89              DAVIDE    FASCIA C: NATI NEL 2012-2011
# 90             GIACOMO  FASCIA A: NATI DAL 2015 IN POI
# 91            LEONARDO  FASCIA A: NATI DAL 2015 IN POI
# 92                LIEN    FASCIA B: NATI NEL 2014-2013
# 93                ALEX    FASCIA D: NATI NEL 2010-2009
# 94             CLAUDIU    FASCIA C: NATI NEL 2012-2011
# 95              GIULIA    FASCIA D: NATI NEL 2010-2009
# 96              MANUEL    FASCIA C: NATI NEL 2012-2011
# 97              ISMAIL  FASCIA A: NATI DAL 2015 IN POI
# 98               WALID  FASCIA A: NATI DAL 2015 IN POI
# 99               LEONE  FASCIA A: NATI DAL 2015 IN POI
# 100           FEDERICO  FASCIA A: NATI DAL 2015 IN POI
# 101              ELISA    FASCIA B: NATI NEL 2014-2013
# 102             DAVIDE    FASCIA C: NATI NEL 2012-2011
# 103            FILIPPO  FASCIA A: NATI DAL 2015 IN POI
# 104            ALESSIA    FASCIA B: NATI NEL 2014-2013
# 105            LORENZO    FASCIA B: NATI NEL 2014-2013
# 106             ANDREA  FASCIA A: NATI DAL 2015 IN POI
# 107              LAURA    FASCIA B: NATI NEL 2014-2013
# 108              MARCO    FASCIA C: NATI NEL 2012-2011
# 109               ALEX    FASCIA C: NATI NEL 2012-2011
# 110             THOMAS    FASCIA D: NATI NEL 2010-2009
# 111          SEBASTIAN  FASCIA A: NATI DAL 2015 IN POI
# 112            LORENZO    FASCIA B: NATI NEL 2014-2013
# 113           LEONARDO    FASCIA C: NATI NEL 2012-2011
# 114              ERISA    FASCIA C: NATI NEL 2012-2011
# 115            LORENZO    FASCIA C: NATI NEL 2012-2011
# 116             ILJANA    FASCIA C: NATI NEL 2012-2011
#
#                            Cintura Kata_Percorso
# 0    BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 1    BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 2    BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 3    BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 4    BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 5    BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 6          GIALLO/ARANCIO, ARANCIO          KATA
# 7          GIALLO/ARANCIO, ARANCIO          KATA
# 8          GIALLO/ARANCIO, ARANCIO          KATA
# 9          GIALLO/ARANCIO, ARANCIO          KATA
# 10         GIALLO/ARANCIO, ARANCIO          KATA
# 11         GIALLO/ARANCIO, ARANCIO          KATA
# 12         GIALLO/ARANCIO, ARANCIO          KATA
# 13         GIALLO/ARANCIO, ARANCIO          KATA
# 14         GIALLO/ARANCIO, ARANCIO          KATA
# 15            ARANCIO/VERDE, VERDE          KATA
# 16            ARANCIO/VERDE, VERDE          KATA
# 17            ARANCIO/VERDE, VERDE          KATA
# 18            ARANCIO/VERDE, VERDE          KATA
# 19                  VERDE/BLU, BLU          KATA
# 20                  VERDE/BLU, BLU          KATA
# 21            BLU/MARRONE, MARRONE          KATA
# 22            BLU/MARRONE, MARRONE          KATA
# 23            BLU/MARRONE, MARRONE          KATA
# 24   BIANCA, BIANCO/GIALLA, GIALLA      PERCORSO
# 25   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 26   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 27              MARRONE/NERA, NERA          KATA
# 28   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 29   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 30         GIALLO/ARANCIO, ARANCIO          KATA
# 31                  VERDE/BLU, BLU          KATA
# 32   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 33   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 34         GIALLO/ARANCIO, ARANCIO          KATA
# 35              MARRONE/NERA, NERA          KATA
# 36         GIALLO/ARANCIO, ARANCIO          KATA
# 37         GIALLO/ARANCIO, ARANCIO          KATA
# 38            ARANCIO/VERDE, VERDE          KATA
# 39   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 40         GIALLO/ARANCIO, ARANCIO          KATA
# 41   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 42   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 43                  VERDE/BLU, BLU          KATA
# 44         GIALLO/ARANCIO, ARANCIO          KATA
# 45            ARANCIO/VERDE, VERDE          KATA
# 46   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 47         GIALLO/ARANCIO, ARANCIO          KATA
# 48         GIALLO/ARANCIO, ARANCIO          KATA
# 49         GIALLO/ARANCIO, ARANCIO          KATA
# 50   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 51   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 52                  VERDE/BLU, BLU          KATA
# 53         GIALLO/ARANCIO, ARANCIO          KATA
# 54         GIALLO/ARANCIO, ARANCIO          KATA
# 55         GIALLO/ARANCIO, ARANCIO          KATA
# 56         GIALLO/ARANCIO, ARANCIO          KATA
# 57         GIALLO/ARANCIO, ARANCIO          KATA
# 58   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 59                  VERDE/BLU, BLU          KATA
# 60            ARANCIO/VERDE, VERDE          KATA
# 61            ARANCIO/VERDE, VERDE          KATA
# 62            ARANCIO/VERDE, VERDE          KATA
# 63            ARANCIO/VERDE, VERDE          KATA
# 64            ARANCIO/VERDE, VERDE          KATA
# 65         GIALLO/ARANCIO, ARANCIO          KATA
# 66         GIALLO/ARANCIO, ARANCIO          KATA
# 67   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 68            BLU/MARRONE, MARRONE          KATA
# 69                  VERDE/BLU, BLU          KATA
# 70            BLU/MARRONE, MARRONE          KATA
# 71            BLU/MARRONE, MARRONE          KATA
# 72            BLU/MARRONE, MARRONE          KATA
# 73            BLU/MARRONE, MARRONE          KATA
# 74            BLU/MARRONE, MARRONE          KATA
# 75            BLU/MARRONE, MARRONE          KATA
# 76            BLU/MARRONE, MARRONE          KATA
# 77                  VERDE/BLU, BLU          KATA
# 78                  VERDE/BLU, BLU          KATA
# 79            BLU/MARRONE, MARRONE          KATA
# 80            BLU/MARRONE, MARRONE          KATA
# 81                  VERDE/BLU, BLU          KATA
# 82         GIALLO/ARANCIO, ARANCIO          KATA
# 83         GIALLO/ARANCIO, ARANCIO          KATA
# 84         GIALLO/ARANCIO, ARANCIO          KATA
# 85   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 86   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 87   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 88   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 89   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 90   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 91   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 92   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 93         GIALLO/ARANCIO, ARANCIO          KATA
# 94         GIALLO/ARANCIO, ARANCIO          KATA
# 95            BLU/MARRONE, MARRONE          KATA
# 96            BLU/MARRONE, MARRONE          KATA
# 97   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 98   BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 99            ARANCIO/VERDE, VERDE          KATA
# 100        GIALLO/ARANCIO, ARANCIO          KATA
# 101  BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 102                 VERDE/BLU, BLU          KATA
# 103  BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 104        GIALLO/ARANCIO, ARANCIO          KATA
# 105           BLU/MARRONE, MARRONE          KATA
# 106  BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 107  BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 108           ARANCIO/VERDE, VERDE          KATA
# 109        GIALLO/ARANCIO, ARANCIO          KATA
# 110        GIALLO/ARANCIO, ARANCIO          KATA
# 111  BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 112        GIALLO/ARANCIO, ARANCIO          KATA
# 113        GIALLO/ARANCIO, ARANCIO          KATA
# 114  BIANCA, BIANCO/GIALLA, GIALLA          KATA
# 115                 VERDE/BLU, BLU          KATA
# 116           ARANCIO/VERDE, VERDE          KATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Società        117 non-null    object
#  1   Cognome        117 non-null    object
#  2   Nome           117 non-null    object
#  3   Anno_Nascita   117 non-null    object
#  4   Cintura        117 non-null    object
#  5   Kata_Percorso  117 non-null    object
# dtypes: object(6)
# memory usage: 5.6+ KB

# %%
dizionario_df = {}

for _, gruppo_anno in df.groupby('Anno_Nascita'):
    for _, gruppo_cintura in gruppo_anno.groupby('Cintura'):
        title = f"{gruppo_cintura['Anno_Nascita'].iloc[0][:8]} - {gruppo_cintura['Cintura'].iloc[0].replace(', ', '-').replace('/', '')}"
        
        if len(gruppo_cintura) > 10:
            pool1, pool2 = [], []
            gruppo_cintura = gruppo_cintura.sort_values(by='Società')
            
            for _, atleta in gruppo_cintura.iterrows():
                if len(pool1) <= len(pool2):
                    pool1.append(atleta)
                else:
                    pool2.append(atleta)

            pool1_df = pd.DataFrame(pool1)
            pool2_df = pd.DataFrame(pool2)

            for pool_num, pool_df in enumerate([pool1_df, pool2_df], 1):
                pool_title = f"{title} POOL-{pool_num}"
                pool_df['NOME KATA'] = ''
                pool_df['1'] = ''
                pool_df['2'] = ''
                pool_df['3'] = ''
                pool_df['4'] = ''
                pool_df['5'] = ''
                pool_df['TOT'] = ''
                dizionario_df[pool_title] = pool_df

        else:
            gruppo_cintura['NOME KATA'] = ''
            gruppo_cintura['1'] = ''
            gruppo_cintura['2'] = ''
            gruppo_cintura['3'] = ''
            gruppo_cintura['4'] = ''
            gruppo_cintura['5'] = ''
            gruppo_cintura['TOT'] = ''
            dizionario_df[title] = gruppo_cintura

# %%
import os
import openpyxl
from openpyxl.styles import Alignment, Border, Side, PatternFill, Font
from openpyxl.worksheet.page import PageMargins
from openpyxl.utils import get_column_letter

# Definisci i colori di sfondo
header_fill = PatternFill(start_color="D3D3D3", end_color="D3D3D3", fill_type="solid")
yellow_fill = PatternFill(start_color="FFFFCC", end_color="FFFFCC", fill_type="solid")

# Font per il titolo
title_font = Font(size=14, bold=True)
hair_border = Border(left=Side(style='hair'), right=Side(style='hair'), top=Side(style='hair'), bottom=Side(style='hair'))

# Crea la cartella 'risultato' se non esiste
if not os.path.exists('risultato'):
    os.makedirs('risultato')

for title, x in dizionario_df.items():
    file_name = f"risultato/{title}.xlsx"

    x = x.copy().drop(columns=['Anno_Nascita', 'Cintura', 'Kata_Percorso'])
    x = x.sample(frac=1).sample(frac=1).sample(frac=1).sample(frac=1).sample(frac=1)
    
    # Salva con offset di 2 righe per il titolo e la riga vuota
    x.to_excel(file_name, sheet_name='Foglio1', startrow=2, index=True)

    # Apri il file Excel e seleziona il foglio di lavoro
    wb = openpyxl.load_workbook(file_name)
    ws = wb['Foglio1']

    # Imposta varie opzioni di pagina
    ws.page_setup.orientation = ws.ORIENTATION_LANDSCAPE
    ws.page_margins = PageMargins(left=0.2, right=0.2, top=0.8, bottom=0.2)
    ws.page_setup.fitToPage = True
    ws.page_setup.fitToHeight = 1
    ws.page_setup.fitToWidth = 1

    # Inserisci il titolo e unisci le celle
    ws['A1'] = title
    ws['A1'].font = title_font
    ws['A1'].alignment = Alignment(horizontal='center')
    ws.merge_cells(start_row=1, start_column=1, end_row=1, end_column=ws.max_column)

    # Loop per ogni cella
    for row in ws.iter_rows(min_row=3):  # Inizia dalla 3ª riga
        for cell in row:
            # Imposta l'altezza delle righe a 30
            ws.row_dimensions[cell.row].height = 30

            # Imposta l'allineamento
            if cell.column == 1 or (cell.column >= 6 and cell.column <= 11):
                cell.alignment = Alignment(vertical='center', horizontal='center')
            else:
                cell.alignment = Alignment(vertical='center', horizontal='left')

            if cell.row > 3 and cell.column > 1:
                cell.border = hair_border
        
            # Imposta il colore di sfondo per l'header (3ª riga)
            if cell.row == 3:
                cell.fill = header_fill

            # Imposta il bordo per la colonna J (10ª colonna)
            if cell.column == 11:
                if cell.row == 3:
                    cell.border = Border(top=Side(style='thin'), left=Side(style='thin'), right=Side(style='thin'), bottom=Side(style='thin'))
                elif cell.row == ws.max_row:
                    cell.border = Border(bottom=Side(style='thin'), left=Side(style='thin'), right=Side(style='thin'))
                else:
                    cell.border = Border(left=Side(style='thin'), right=Side(style='thin'), bottom=Side(style='hair'), top=Side(style='hair'))

            # Imposta i colori di sfondo alternati per le righe
            if cell.row > 3 and cell.row % 2 == 1:
                cell.fill = yellow_fill

    # Imposta l'area di stampa e la larghezza delle colonne
    max_row = ws.max_row
    max_col = get_column_letter(ws.max_column)
    ws.page_setup.print_area = f"A1:{max_col}{max_row}"
    ws.page_setup.paperSize = ws.PAPERSIZE_A3  # Imposta la dimensione del foglio in A3
    ws.column_dimensions['A'].width = 8.43
    ws.column_dimensions['B'].width = 45.57
    ws.column_dimensions['C'].width = 24.87
    ws.column_dimensions['D'].width = 24.87
    ws.column_dimensions['E'].width = 45.57

    # Salva le modifiche
    wb.save(file_name)
